# %% [markdown]
# # yolo——you only look once
# 这里，只对深度学习方面进行简单引入，并用一个yolo模型进行直观演示。
#
# yolo属于深度学习中的目标识别方向。
#
# 注：
#
# (1)尝试在树莓派3B+上运行yolov3-tiny，但尝试多次失败，经排查，初步定在树莓派内存过小原因，准备后续更换4G内存版树莓派4B进行尝试。如果您有在3B+上的解决方案，麻烦告送我。
#
# (2)当前yolov3-tiny版本在树莓派3B+上运行时间为30s，根本不能用于实际产品，后续会逐步更换处理硬件，例如使用movidius2神经网络棒加速、使用zynq系列使用PL端加速，逐步减少运行时间，最终能满足实际产品应用。

# %%
#在树莓派上上运行yolo模型进行目标检测失败，判断是内存太小了，不够计算机的
from IPython.display import Image
Image(filename = "./picture/yolo_mem_err.jpg", width=800, height=600)

# %% [markdown]
# # 下载，在ubuntu上运行yolo模型
# (1)在jupyter-notebook进入“Notebooks/darknet”目录，下载darknet.md5和darknet_cpu.tar.bz2两个文件，到ubuntu系统上。
#
# (2)使用md5sum计算darknet.tar.bz2校验值，比较该值与darknet.md5中提供的是否一致。
#
# (3)解压darknet.tar.bz2文件，进入该目录，运行指令“sh rebuild.sh”。
#
# (4)解压darknet.tar.bz2，使用指令“sh rebuild.sh”运行脚本，重新编译程序。
#
# (5)使用指令“sh detect_example.sh”进行目标检测

# %%
#在ubuntu上运行yolo模型进行目标检测
from IPython.display import Image
Image(filename = "./picture/yolo_detect.jpg", width=800, height=600)
